# %% [markdown]
# <a href="https://colab.research.google.com/github/pothineni1/AIML/blob/main/Pandas/Pandas_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.3

# %%
print(dir(pd))
# Out:
# ['ArrowDtype', 'BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt8Dtype', '__all__', '__annotations__', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_built_with_meson', '_config', '_is_numpy_dev', '_libs', '_pandas_datetime_CAPI', '_pandas_parser_CAPI', '_testing', '_typing', '_version_meson', 'annotations', 'api', 'array', 'arrays', 'bdate_ran
# ...

# %% [markdown]
# ## Series Data - single dimention only one column

# %%
age = [21,22,23,24,45]
df1 = pd.Series(age, name = 'Age')
df1
# Out:
# 0    21
# 1    22
# 2    23
# 3    24
# 4    45
# Name: Age, dtype: int64

# %%
df1.max() , df1.min(), df1.mean(), df1.median, df1.mode, df1.std()
# Out:
# (45,
#  21,
#  np.float64(27.0),
#  <bound method Series.median of 0    21
#  1    22
#  2    23
#  3    24
#  4    45
#  Name: Age, dtype: int64>,
#  <bound method Series.mode of 0    21
#  1    22
#  2    23
#  3    24
#  4    45
#  Name: Age, dtype: int64>,
#  10.124228365658293)

# %%
for i in df1:
  print(i)
# Out:
# 21
# 22
# 23
# 24
# 45

# %% [markdown]
# Data Frame -- Multi dimention rows and columns

# %%
df2 = pd.DataFrame([[21,2,25000],[22,3,26000],[30,10,50000],[35,15,100000]], columns= ['Age','Exp','Sal'])
##display(df2)
df2
# Out:
#    Age  Exp     Sal
# 0   21    2   25000
# 1   22    3   26000
# 2   30   10   50000
# 3   35   15  100000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     4 non-null      int64
#  1   Exp     4 non-null      int64
#  2   Sal     4 non-null      int64
# dtypes: int64(3)
# memory usage: 228.0 bytes

# %%
df3 = pd.read_csv('/content/sample_data/california_housing_train.csv')
df3
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...
